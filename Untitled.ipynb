# %%
import numpy as np

arr = np.array([1, 2, 3, 4, 5])
arr
# Out:
# array([1, 2, 3, 4, 5])

# %%
# Out:
#   Cell In[2], line 7
#     git add notebook/my-1st-jupyter-notebook.ipynb
#                         ^
# SyntaxError: invalid decimal literal
